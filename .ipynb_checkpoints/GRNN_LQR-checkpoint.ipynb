# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import networkx as nx

# %%
# %matplotlib inline
np.set_printoptions(precision=3)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Distributed LQR environment

# %%
N = 20
T = 50
NTK = 5 + 1 # Neighbors to keep

# Create and visualize graph
rand_vec = np.random.random(N)
S = np.zeros((N,N))
for i in range(N):
  inds = np.abs(rand_vec-rand_vec[i]).argpartition(NTK)[:NTK]
  S[np.ones(NTK, dtype=int)*i, inds] = 1
  S[inds, np.ones(NTK, dtype=int)*i] = 1
G = nx.Graph(S)
nx.draw_kamada_kawai(G)

# Normalize graph shift operator S
S = S / np.linalg.norm(S, ord=2)

# Generate A, B
eig_vecs = np.linalg.eig(S)[1]
A = eig_vecs @ np.diag(np.random.randn(N)) @ eig_vecs.T
B = eig_vecs @ np.diag(np.random.randn(N)) @ eig_vecs.T
A = A / np.linalg.norm(A, ord=2) * 0.995
B = B / np.linalg.norm(B, ord=2)

# Generate Q, R
Q = np.eye(N)
R = np.eye(N)

# Cast into tensor
S = torch.tensor(S).to(device)
A = torch.tensor(A, dtype=torch.double).to(device)
B = torch.tensor(B, dtype=torch.double).to(device)
Q = torch.tensor(Q).to(device)
R = torch.tensor(R).to(device)

# %%
# TODO: enable batch processing
def sim_forward(x0, controller, A, B, T, device):
  N = S.size(0)
  x = torch.zeros((T+1, N), dtype=torch.double, device=device)
  x[0,:] = x0
  u = torch.zeros((T, N), dtype=torch.double, device=device)
  for i in range(T):
    ui = controller(x[i,:]).to(device)
    x[i+1,:] = A @ x[i,:] + B @ ui
    u[i,:] = ui
  return x, u

# %%
##NIK: helper code to construct a robust Lyapunov function x'Px from LQR solution
##TODO: convert everything back to tensors and send to device
def spectral_radius(A):
    return np.max(np.abs(np.linalg.eigvals(A)))

def dlqr(A,B,Q=None,R=None):
    """Solve the discrete time lqr controller.
    x[k+1] = A x[k] + B u[k]
    cost = sum x[k].T*Q*x[k] + u[k].T*R*u[k]
    """
    # ref Bertsekas, p.151
    if Q is None:
        Q = np.eye(A.shape[0])
    if R is None:
        R = np.eye(B.shape[1])

    P = sp.linalg.solve_discrete_are(A, B, Q, R)
    K = -sp.linalg.solve(B.T.dot(P).dot(B) + R, B.T.dot(P).dot(A), sym_pos=True)
    

    A_c = A + B.dot(K)
    TOL = 1e-5
    if spectral_radius(A_c) >= 1 + TOL:
        print("WARNING: spectral radius of closed loop is:", spectral_radius(A_c))

    return P, K

P, K_lqr = dlqr(A.detach().cpu().numpy(), B.detach().cpu().numpy(),
                Q.detach().cpu().numpy(), R.detach().cpu().numpy())

## PARAMETERS FOR EXPERT ROBUST LYAP FUNCTION
## rho = exponential decay rate of lyapunov function
## eps = some robustness
rho = 0.9
one_minus_rho = 1 - .9
eps = .01

# Solve for solution to (A + B K_lqr)' X (A + B K_lqr) - X + Q = 0 with Q = (1-\rho)X + eps I 
# s.t. Acl ' X Acl = \rho X - eps I <= \rho X (note transpose on Acl in DLYAP because of scipy implementation)
# V(x) = x'Xx, s.t. V(x(t+1)) <= rho V(x(t)), (Acl x)'X(Acl x) <= x' X x' 
X = sp.linalg.solve_discrete_lyapunov((A + B @ K_lqr).T, one_minus_rho * P + eps * np.eye(P.shape[0]))

# Add stability regularizer to cost using something along these lines
def lyapunov_function(X, state):
    return np.dot(state, X.dot(state))

def decrease_soft_constraint(X, x, controller):
    def f_closed_loop(x):
        return A.dot(x) + B.dot(controller(x))
    V_plus = lyapunov_function(X, f_closed_loop(x))
    V_cur = lyapunov_function(X, x)
    return np.maximum(V_plus - rho * V_cur, 0.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e0b776e04ed4> in <module>()
#      27
#      28 P, K_lqr = dlqr(A.detach().cpu().numpy(), B.detach().cpu().numpy(),
# ---> 29                 Q.detach().cpu().numpy(), R.detach().cpu().numpy())
#      30
#      31 ## PARAMETERS FOR EXPERT ROBUST LYAP FUNCTION
#
# <ipython-input-6-e0b776e04ed4> in dlqr(A, B, Q, R)
#      15         R = np.eye(B.shape[1])
#      16
# ---> 17     P = sp.linalg.solve_discrete_are(A, B, Q, R)
#      18     K = -sp.linalg.solve(B.T.dot(P).dot(B) + R, B.T.dot(P).dot(A), sym_pos=True)
#      19
#
# NameError: name 'sp' is not defined

# %%
# note that * has higher precedence than @ (stupid python syntex)
def LQ_cost(x, u, Q, R):
  return torch.sum(x * (x @ Q)) + torch.sum(u * (u @ R))

# %% [markdown]
# ## Vanilla GRNN Model

# %%
class GRNN(nn.Module):
    def __init__(self, S, N, T, p=1, q=1, h=5):
        super().__init__()
        self.N, self.T, self.p, self.q, self.h = N, T, p, q, h
        # Initialize S
        if S is None:
          # If S is none, we treat the graph topology as a parameter we want to
          # optimize
          initial_S = torch.rand((N,N))
          initial_S = initial_S / initial_S.sum(1)[:,None]
          self.register_parameter(name='S', param=torch.nn.Parameter(initial_S))
        else:
          # If S is given, we do not design the topology and just focus on finding
          # the optimal controller
          self.S = S
        self.register_parameter(name='A',
                                param=torch.nn.Parameter(torch.randn(p,h, dtype=torch.double)))
        self.register_parameter(name='B',
                                param=torch.nn.Parameter(torch.randn(h,q, dtype=torch.double)))
        
    def graph_conv(self, X, Z):
        Z_new = torch.tanh( torch.matmul(self.S, Z) + torch.matmul(X, self.A) )
        u = torch.mm(Z_new, self.B)
        return Z_new, u

    def forward(self, x0, A_, B_):
        # Change the notation here later. A_ (dynamics) =/= A (network parameter)
        x_traj = self.S.new_empty((self.T+1, self.N, self.q))
        u_traj = self.S.new_empty((self.T, self.N, self.q))
        x_traj[0,:,:] = torch.unsqueeze(x0,1)#x0[:, None]
        Z = self.S.new_zeros((self.T+1,self.N, self.h))
        for t in range(T):
          # Something annoying about the in-place operations here with pytorch
          # Hence the .clone() for some of the tensors we are using
          xt = x_traj[t].clone()
          Zt, ut = self.graph_conv(xt, Z[t,:,:].clone())
          x_traj[t+1] = A_ @ xt + B_ @ ut
          u_traj[t] = ut
          Z[t+1] = Zt
        return x_traj, u_traj

# %%
def criterion(x_traj, u_traj, Q, R):
  # The x and u trajectories are of size (50,20,1) right out of the GRNN
  return LQ_cost(x_traj[:,:,0], u_traj[:,:,0], Q, R)

# %% [markdown]
# ## Training the GRNN for dist. LQR

# %%
model = GRNN(S, N, T, p=1, q=1, h=5).to(device)

# %%
def train_it(model, N, A, B, Q, R, beta=0, batch_size=20):
  error = 0
  for i in range(batch_size):
    x0 = torch.randn(N)
    xtraj, utraj = model.forward(x0, A, B)
    error += criterion(xtraj, utraj, Q, R)
  regularization = torch.norm(model.S,1)
  loss = error / batch_size + beta * regularization
  return loss

# %%
def train_model(S, N, T, A, B, Q, R, beta=0, num_epoch=100, verbose=False):
    model = GRNN(S, N, T).to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.01)
    for epoch in range(num_epoch):
        model.zero_grad()
        loss = train_it(model, N, A, B, Q, R, beta=beta)
        if(verbose and epoch % 10 == 0):
            print('Epoch: {} \t Loss: {}'.format(epoch+1, loss.item()))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 10)
        optimizer.step()
    return model

# %%
model = train_model(S, N, T, A, B, Q, R, beta=0, num_epoch=100, verbose=True)
# Out:
# Epoch: 1 	 Loss: 37477.79030669155
# Epoch: 11 	 Loss: 24702.383365280017
# Epoch: 21 	 Loss: 9791.404067547155
# Epoch: 31 	 Loss: 359.0108789483566
# Epoch: 41 	 Loss: 47.948303633172635
# Epoch: 51 	 Loss: 48.746015169372164
# Epoch: 61 	 Loss: 48.966281073678395
# Epoch: 71 	 Loss: 39.315647331655086
# Epoch: 81 	 Loss: 37.06520886733108
# Epoch: 91 	 Loss: 39.05995495825162

# %% [markdown]
# ## Experiments

# %%
# Solve LQR for comparison
def lqr_recursion(A, B, Q, R, T):
  # Assume dynamics is time-invariant
  n, m = B.size()
  Ks = Q.new_zeros((T, m, n))
  Vk = Q.clone()
  Kk = Q.new_zeros((m, n))
  with torch.no_grad():
    for k in range(T):
      Kk = -torch.inverse(R + B.T @ Vk @ B) @ B @ Vk @ A
      Vk = Q + Kk.T @ R @ Kk + (A + B @ Kk).T @ Vk @ (A + B @ Kk)
      Ks[T-k-1] = Kk
  return Ks

class LQRController:
  def __init__(self, A, B, Q, R, T):
    self.Ks = lqr_recursion(A, B, Q, R, T)
    self.counter = 0
  
  def control(self, x):
    u = self.Ks[self.counter] @ x
    self.counter += 1
    return u

# %%
x0 = torch.randn(N, dtype=torch.double).to(device)
# Visualize the trajectory of our GNN controller
x_gnn, u_gnn = model.forward(x0, A, B)
cost_gnn = LQ_cost(x_gnn[:,:,0], u_gnn[:,:,0], Q, R).cpu().item()
x_gnn = x_gnn.detach().cpu().numpy()

# Visualize the trajectory of the autonomous system
controller = lambda x: torch.zeros(N, dtype=torch.double, device=device)
x_auto, u_auto = sim_forward(x0, controller, A, B, T, device)
cost_auto = LQ_cost(x_auto, u_auto, Q, R).cpu().item()

# Visualize the trajectory of the system with random control
controller = lambda x: torch.randn(N, dtype=torch.double, device=device)
x_rand, u_rand = sim_forward(x0, controller, A, B, T, device)
cost_rand = LQ_cost(x_rand, u_rand, Q, R).cpu().item()

# Visualize the trajectory of optimal global LQR control
controller = LQRController(A, B, Q, R, T)
x_opt, u_opt = sim_forward(x0, controller.control, A, B, T, device)
cost_opt = LQ_cost(x_opt, u_opt, Q, R).cpu().item()

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,4,1)
for i in range(N):
  plt.plot(np.arange(51), x_opt[:,i])
  plt.title('Optimal\nCost={:.3f}'.format(cost_opt))

plt.subplot(1,4,2)
for i in range(N):
  plt.plot(np.arange(51), x_gnn[:,i])
  plt.title('GNN\nCost={:.3f}'.format(cost_gnn))

plt.subplot(1,4,3)
for i in range(N):
  plt.plot(np.arange(51), x_auto[:,i])
  plt.title('Autonomous\nCost={:.3f}'.format(cost_auto))

plt.subplot(1,4,4)
for i in range(N):
  plt.plot(np.arange(51), x_rand[:,i])
  plt.title('Random\nCost={:.3f}'.format(cost_rand))

# %%
myS = torch.tensor(torch.abs(model.S)>0.001,dtype=torch.uint8).detach().cpu().numpy()
G = nx.Graph(myS)
nx.draw_kamada_kawai(G)
torch.sum(torch.tensor(((torch.abs(model.S)>.001)),dtype=torch.uint8))
